# %%
#  CHALLENGE ONE

# %%
import pandas as pd
import requests
from sqlalchemy import create_engine
from bs4 import BeautifulSoup
import regex as re
import numpy as np
import modin.pandas as mp

# %%
full_set = pd.read_csv('../raw_data/full_set.csv')

# %%
challenge_1_df = full_set[['job_name', 'country', 'gender','uuid']]
challenge_1_df
# Out:
#                                job_name   country  gender  \
# 0                                   NaN   Austria    Male
# 1     automatic data processing planner   Austria    Male
# 2                                   NaN   Austria    Male
# 3                      data coordinator   Austria    Male
# 4                    database developer   Austria  Female
# ...                                 ...       ...     ...
# 9644           data warehouse developer  Slovakia  Female
# 9645                   database manager  Slovakia    Male
# 9646                                NaN  Slovakia    Male
# 9647                       data officer  Slovakia    Male
# 9648                     data scientist  Slovakia  Female
#
#                                       uuid
# 0     f6e7ee00-deac-0133-4de8-0a81e8b09a82
# 1     54f0f1c0-dda1-0133-a559-0a81e8b09a82
# 2     83127080-da3d-0133-c74f-0a81e8b09a82
# 3     15626d40-db13-0133-ea5c-0a81e8b09a82
# 4     24954a70-db98-0133-4a64-0a81e8b09a82
# ...                                    ...
# 9644  7d1ac020-dcb4-0133-817a-0a81e8b09a82
# 9645  39f989f0-db52-0133-8482-0a81e8b09a82
# 9646  70ce4a90-d965-0133-f5e4-0a81e8b09a82
# 9647  2896e440-db3c-0133-5b67-0a81e8b09a82
# 9648  06217ba0-dd56-0133-edda-0a81e8b09a82
#
# [9649 rows x 4 columns]

# %%
challenge_1df = challenge_1_df.groupby(['country','job_name','gender',])['uuid'].count().reset_index()

# %%
challenge_1df.rename(columns={'country':'Country','job_name':'Job Title','gender':'Gender','uuid':'Quantity'},inplace=True)

# %%
challenge_1df
# Out:
#                                                 Country  \
# 0                                               Austria
# 1                                               Austria
# 2                                               Austria
# 3                                               Austria
# 4                                               Austria
# ...                                                 ...
# 2581  United Kingdom of Great Britain and Northern I...
# 2582  United Kingdom of Great Britain and Northern I...
# 2583  United Kingdom of Great Britain and Northern I...
# 2584  United Kingdom of Great Britain and Northern I...
# 2585  United Kingdom of Great Britain and Northern I...
#
#                                               Job Title  Gender  Quantity
# 0     automatic data processing customer liaison adp...    Male         2
# 1                     automatic data processing planner  Female         1
# 2                     automatic data processing planner    Male         1
# 3     automatic data processing systems security spe...    Male         2
# 4                              clinical data specialist    Male         1
# ...                                                 ...     ...       ...
# 2581  scada operator supervisory control and data ac...  Female         1
# 2582  scada technician supervisory control and data ...    Male         1
# 2583                         sql database administrator  Female         3
# 2584                         sql database administrator    Male         5
# 2585                             survey data technician    Male         1
#
# [2586 rows x 4 columns]

# %%
challenge_1df['Percentage %'] = challenge_1df['Quantity']/challenge_1df['Quantity'].sum()*100

# %%
challenge_1df.to_csv('../final_data/challenge_1.csv',index=False)
