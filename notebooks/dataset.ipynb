# %%
import pandas as pd
from sqlalchemy import create_engine


path = '/home/emmanuel/Desktop/descarga_db/raw_data_project_m1.db'
engine = create_engine(f'sqlite:///{path}')

raw_df = pd.read_sql_query("SELECT * FROM sqlite_master WHERE type='table'", engine)

raw_df
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table  personal_info  personal_info         2
# 1  table   country_info   country_info       401
# 2  table    career_info    career_info       762
# 3  table      poll_info      poll_info      1168
#
#                                                  sql
# 0  CREATE TABLE personal_info (\n\tuuid TEXT NOT ...
# 1  CREATE TABLE country_info (\n\tuuid TEXT NOT N...
# 2  CREATE TABLE career_info (\n\tuuid TEXT NOT NU...
# 3  CREATE TABLE poll_info (\n\tuuid TEXT NOT NULL...

# %%
df_raw = pd.read_sql("""SELECT personal_info.uuid,
personal_info.age,
personal_info.dem_has_children,
personal_info.gender,
career_info.dem_education_level,
career_info.dem_full_time_job,
career_info.normalized_job_code,
country_info.country_code,
poll_info.question_bbi_2016wave4_basicincome_argumentsagainst,
poll_info.question_bbi_2016wave4_basicincome_argumentsfor,
poll_info.question_bbi_2016wave4_basicincome_awareness 
FROM personal_info
JOIN career_info 
ON career_info.uuid = personal_info.uuid
JOIN country_info 
ON country_info.uuid = personal_info.uuid
JOIN poll_info 
ON poll_info.uuid = country_info.uuid 
GROUP BY career_info.uuid;""",engine)
df_raw
# Out:
#                                       uuid           age dem_has_children  \
# 0     0001afe0-da16-0133-9d54-0a81e8b09a82  31 years old               nO
# 1     00073240-d995-0133-f7e1-0a81e8b09a82  35 years old               NO
# 2     0007b2d0-daf3-0133-c5f0-0a81e8b09a82          1988              YES
# 3     00199e00-d8c3-0133-c6b2-0a81e8b09a82          2000               NO
# 4     0028cc20-dcc4-0133-f408-0a81e8b09a82          1988              YES
# ...                                    ...           ...              ...
# 9644  ffe6bd40-d98a-0133-a373-0a81e8b09a82  53 years old              YES
# 9645  fff34480-db17-0133-381a-0a81e8b09a82  45 years old               nO
# 9646  fffa2a60-dc71-0133-8480-0a81e8b09a82  53 years old              yES
# 9647  fffcd3a0-d975-0133-b045-0a81e8b09a82  38 years old               NO
# 9648  ffffd3f0-da39-0133-da0f-0a81e8b09a82  44 years old              YES
#
#       gender dem_education_level dem_full_time_job  \
# 0       male                high               yes
# 1       male              medium                no
# 2     FeMale              medium               yes
# 3       Male                 low                no
# 4     female                high                no
# ...      ...                 ...               ...
# 9644    male              medium               yes
# 9645    male                high               yes
# 9646  female                 low                no
# 9647    Male                high                no
# 9648    Male                high               yes
#
#                    normalized_job_code country_code  \
# 0     7932d4705d002b47789c11edfaed685e           NL
# 1                                 None           HR
# 2     e7b3e1c6a32c7247cd4857e4c3574165           DE
# 3                                 None           IT
# 4                                 None           FR
# ...                                ...          ...
# 9644  ac47656fd51c2cd8037057262c910dc4           FR
# 9645  ac47656fd51c2cd8037057262c910dc4           DE
# 9646                              None           ES
# 9647                              None           LT
# 9648  d06dfb43c95b585a89ae556c9221b573           FR
#
#      question_bbi_2016wave4_basicincome_argumentsagainst  \
# 0     Foreigners might come to my country and take a...
# 1                                     None of the above
# 2     It might encourage people to stop working | It...
# 3                                     None of the above
# 4     It is against the principle of linking merit a...
# ...                                                 ...
# 9644  Only the people who need it most should get so...
# 9645  Foreigners might come to my country and take a...
# 9646  Only the people who need it most should get so...
# 9647          It might encourage people to stop working
# 9648  It increases dependence on the state | It is i...
#
#         question_bbi_2016wave4_basicincome_argumentsfor  \
# 0     It reduces bureaucracy and administrative expe...
# 1                                     None of the above
# 2     It reduces bureaucracy and administrative expe...
# 3                                     None of the above
# 4                                     None of the above
# ...                                                 ...
# 9644     It reduces anxiety about financing basic needs
# 9645            It creates more equality of opportunity
# 9646                                  None of the above
# 9647  It creates more equality of opportunity | It r...
# 9648                                  None of the above
#
#      question_bbi_2016wave4_basicincome_awareness
# 0                       I know something about it
# 1                        I have never heard of it
# 2             I have heard just a little about it
# 3                        I have never heard of it
# 4                       I know something about it
# ...                                           ...
# 9644                    I know something about it
# 9645                    I know something about it
# 9646          I have heard just a little about it
# 9647                        I understand it fully
# 9648                    I know something about it
#
# [9649 rows x 11 columns]

# %%
#personal_info = pd.read_sql("SELECT * FROM personal_info",engine)
#personal_info
#country = pd.read_sql("SELECT * FROM country_info",engine)
#country
#career = pd.read_sql("SELECT * FROM career_info",engine)
#career
#poll_info = pd.read_sql("SELECT * FROM poll_info",engine)
#poll_info

# %%
import requests

# %%
req = requests.get('http://api.dataatwork.org/v1/jobs?limit=500')

req.json()
# Out:
# [{'uuid': '26bc4486dfd0f60b3bb0d8d64e001800',
#   'title': '1st Grade Teacher',
#   'normalized_job_title': '1st grade teacher',
#   'parent_uuid': '51cc95467c1844c7dc1d923265c023b2'},
#  {'uuid': '9be6e14491305132c175cb1781a3356c',
#   'title': '1st Pressman',
#   'normalized_job_title': '1st pressman',
#   'parent_uuid': '96f1cf15fe5880d8660c70f0756944ab'},
#  {'uuid': 'd38d16bab3f9f25ae34ae3e2aad254d4',
#   'title': '1st Pressman On Web Press',
#   'normalized_job_title': '1st pressman on web press',
#   'parent_uuid': '96f1cf15fe5880d8660c70f0756944ab'},
#  {'uuid': '8576a78b5c1cae3a567ca7fd34500357',
#   'title': '21 Dealer',
#   'normalized_job_title': '21 dealer',
#   'parent_uuid': '4be080220c824dcb435d59ebf1c3ce80'},
#  {'uuid': 'a59278d7f653db37e54a270345a91a05',
#   'title': '2nd Grade Teacher',
#   'normalized_job_title': '2nd grade teacher',
#   'parent_uuid': '51cc95467c1844c7dc1d923265c023b2'},
#  {'uuid': '9c631442c4966cd3e5a9e52fc70aff1c',
#   'title': '2nd Pressman',
#   'normalized_job_title': '2nd pressman',
#   'parent_uuid': '96f1cf15fe5880d8660c70f0756944ab'},
#  {'uuid': 'f5a2151d370ebca7b49778e036a287e8',
#   'title': '2 Year Olds Preschool Teacher',
#   'normalized_job_title': '2 year olds preschool teacher',
#   'parent_uuid': 'd78b3ba8b749686d739480ee77f9e219'},
#  {'uuid': 'af2e31c2c64ae223b06eb7f0cbf59a98',
#   'title': '3D Animator',
#   'normalized_job_title': '3d animator',
#   'parent_uuid': 'caa551520f21c7c220716a8f82806246'},
#  {'uuid': 'ac029293b0ea43f168b004c4f04fca31',
#   'title': '3D Artist',
#   'normalized_job_title': '3d artist',
#   'parent_uuid': 'caa551520f21c7c220716a8f82806246'},
#  {'uuid': '7d37dfe2eface4ae79db093b0a79385d',
#   'title': '3D Designer',
#   'normalized_job_title': '3d designer',
#   'parent_uuid': 'caa551520f21c7c220716a8f82806246'},
#  {'uuid': '6cb0a6786c08d6c91a4fc9f61e19f62d',
#   'title': '3D Modeler',
#   'normalized_job_title': '3d modeler',
#   'parent_uuid': 'caa551520f21c7c220716a8f82806246'},
#  {'uuid': 'ec45194ae348e1bb21415064364f038b',
#   'title': '3D Specialist',
#   'normalized_job_title': '3d specialist',
#   'parent_uuid': 'caa551520f21c7c220716a8f82806246'},
#  {'uuid': '4266e89fcaf06973fa23fc6f75b27682',
#   'title': '3D Technologist',
#   'normalized_job_title': '3d technologist',
#   'parent_uuid': 'ce1c0fc273d3c803e94a73ff0b54816e'},
#  {'uuid': '0cfb09fa1c6691fd6d77a3d3743fa8bc',
#   'title': '3rd Grade Reading Teacher',
#   'normalized_job_title': '3rd grade reading teacher',
#   'parent_uuid': '51cc95467c1844c7dc1d923265c023b2'},
#  {'uuid': 'ac668f6dc8795ace795b2c1f7c889ba4',
#   'title': '3rd Grade Teacher',
#   'normalized_job_title': '3rd grade teacher',
#   'parent_uuid': '51cc95467c1844c7dc1d923265c023b2'},
#  {'uuid': '7826ba3a7150817935915f63b861936b',
#   'title': '3rd Pressman',
#   'normalized_job_title': '3rd pressman',
#   'parent_uuid': '96f1cf15fe5880d8660c70f0756944ab'},
#  {'uuid': '90bc1d89aaee33a96c1b70fef0750d62',
#   'title': '411 Directory Assistance Operator',
#   'normalized_job_title': '411 directory assistance operator',
#   'parent_uuid': 'f0fc66d367f370fa64da4780019702cd'},
#  {'uuid': '814eb6844cf824e6945fb02a48f0e569',
#   'title': '4-H Youth Development Specialist',
#   'normalized_job_title': '4h youth development specialist',
#   'parent_uuid': '1028b80a2ce2bfb940b2198f487c6abb'},
#  {'uuid': '772053d8bb2c6e127b0bf216e50285ed',
#   'title': '4th Grade Math Teacher',
#   'normalized_job_title': '4th grade math teacher',
#   'parent_uuid': '51cc95467c1844c7dc1d923265c023b2'},
#  {'uuid': 'de0a3e90cdd112dd78120d4c8a9422b2',
#   'title': '4th Grade Teacher',
#   'normalized_job_title': '4th grade teacher',
#   'parent_uuid': '51cc95467c1844c7dc1d923265c023b2'},
#  {'uuid': 'd64fc1cc4fc5c23e7a881eebdabbf760',
#   'title': '4 Year Olds Kindergarten Teacher',
#   'normalized_job_title': '4 year olds kindergarten teacher',
#   'parent_uuid': '3bdd6176ec70d0f9bf99576ef24efe02'},
#  {'uuid': '6ee9380d7aea9af2253c45c3f95e2f2d',
#   'title': '5th Grade Teacher',
#   'normalized_job_title': '5th grade teacher',
#   'parent_uuid': '51cc95467c1844c7dc1d923265c023b2'},
#  {'uuid': '12e214a19f3791f71c62bdcd6db1cb1d',
#   'title': '6th Grade Teacher',
#   'normalized_job_title': '6th grade teacher',
#   'parent_uuid': '51cc95467c1844c7dc1d923265c023b2'},
#  {'uuid': 'b59bbe4adf2689c28d1152f71bd06623',
#   'title': '7th Grade Social Studies Teacher',
#   'normalized_job_title': '7th grade social studies teacher',
#   'parent_uuid': 'b58281863881ea47b56e8ba4a934f0ed'},
#  {'uuid': 'b2c4571c00cf127a9c88439c57d787bc',
#   'title': '7th Grade Teacher',
#   'normalized_job_title': '7th grade teacher',
#   'parent_uuid': 'b58281863881ea47b56e8ba4a934f0ed'},
#  {'uuid': '5f606d3af4d02321374083d98e2e595e',
#   'title': '8th Grade Mathematics Teacher',
#   'normalized_job_title': '8th grade mathematics teacher',
#   'parent_uuid': 'b58281863881ea47b56e8ba4a934f0ed'},
#  {'uuid': '0a91780ba11a571a38329f18858f1c4e',
#   'title': '8th Grade Teacher',
#   'normalized_job_title': '8th grade teacher',
#   'parent_uuid': 'b58281863881ea47b56e8ba4a934f0ed'},
#  {'uuid': 'caea5df756b245c0665b8c3f9b76b835',
#   'title': '911 Communications Manager',
#   'normalized_job_title': '911 communications manager',
#   'parent_uuid': '1b135bfc7ada14a47a7dc7d616256467'},
#  {'uuid': 'c07acbcb79eedc7c1543b9b912f2abd3',
#   'title': '911 Dispatcher',
#   'normalized_job_title': '911 dispatcher',
#   'parent_uuid': 'e7f1bd1ae273fdc720238e73e48b648b'},
#  {'uuid': '8ed03c6f7d056f87cfcaacb6fb822829',
#   'title': '911 Emergency Dispatcher',
#   'normalized_job_title': '911 emergency dispatcher',
#   'parent_uuid': 'e7f1bd1ae273fdc720238e73e48b648b'},
#  {'uuid': 'c4eef070ac5f4b5923d825c9f24f351b',
#   'title': '911 Emergency Services Dispatcher',
#   'normalized_job_title': '911 emergency services dispatcher',
#   'parent_uuid': 'e7f1bd1ae273fdc720238e73e48b648b'},
#  {'uuid': '5c70aac6403b19e16051d3f1c96db20d',
#   'title': '911 Operator (Nine One One Operator)',
#   'normalized_job_title': '911 operator nine one one operator',
#   'parent_uuid': 'e7f1bd1ae273fdc720238e73e48b648b'},
#  {'uuid': '02d0f464635c8a5f9d38e9ead81aabda',
#   'title': '911 Public Safety Dispatcher',
#   'normalized_job_title': '911 public safety dispatcher',
#   'parent_uuid': 'e7f1bd1ae273fdc720238e73e48b648b'},
#  {'uuid': '89eca3ff25f3c7615aba72d210b3277e',
#   'title': '911 Telecommunicator',
#   'normalized_job_title': '911 telecommunicator',
#   'parent_uuid': 'e7f1bd1ae273fdc720238e73e48b648b'},
#  {'uuid': '844b9195809e247b727b9c96882644a6',
#   'title': 'Aadc Plans Staff Officer',
#   'normalized_job_title': 'aadc plans staff officer',
#   'parent_uuid': 'e7fdd7f57854ea7d06958a8b65ce0148'},
#  {'uuid': '9980e4dfcbf3f2af2999d13784876086',
#   'title': 'A Auxiliary',
#   'normalized_job_title': 'a auxiliary',
#   'parent_uuid': '75a75c165df6317d601e1bbca3ec29b5'},
#  {'uuid': '391d21cc64aab7135a4f38f200ef8e5f',
#   'title': 'Abalone Fisherman',
#   'normalized_job_title': 'abalone fisherman',
#   'parent_uuid': '4c1dc68c4aa0c761b3196df6bd7cb9f9'},
#  {'uuid': 'da0d41fba4de5815d5ae1dd622194fe7',
#   'title': 'Abalone Processor',
#   'normalized_job_title': 'abalone processor',
#   'parent_uuid': 'd8a6bdc826f7520bfb69106843bd691b'},
#  {'uuid': '1708c7b27f484865d8891a605b91c27c',
#   'title': 'Abatement Worker',
#   'normalized_job_title': 'abatement worker',
#   'parent_uuid': '74ea93ca3024c3d00d6709ae9e099ad2'},
#  {'uuid': 'c674afc952704491409885ad88bd7fa5',
#   'title': 'Abattoir Supervisor',
#   'normalized_job_title': 'abattoir supervisor',
#   'parent_uuid': 'd72271093395fd0e5f645037b6b68e70'},
#  {'uuid': 'dd3df9c6d769aa52e44081f148c1690a',
#   'title': 'Able Bodied Seaman (AB Seaman)',
#   'normalized_job_title': 'able bodied seaman ab seaman',
#   'parent_uuid': '36b8cb5c52318c6a2e2949e5b1b995c6'},
#  {'uuid': '5acac2c229ecf90349f0b864e8ed1109',
#   'title': 'Able Bodied Tankerman (AB Tankerman)',
#   'normalized_job_title': 'able bodied tankerman ab tankerman',
#   'parent_uuid': '36b8cb5c52318c6a2e2949e5b1b995c6'},
#  {'uuid': '724481bb5df848ef03782a5e45555f92',
#   'title': 'Able Bodied Watchman (AB Watchman)',
#   'normalized_job_title': 'able bodied watchman ab watchman',
#   'parent_uuid': '753caedf8327429ae7038041172ba65a'},
#  {'uuid': '58ec2cf3a2535744065ccddb7fcdfc20',
#   'title': 'Able Bodied Wheelsman (AB Wheelsman)',
#   'normalized_job_title': 'able bodied wheelsman ab wheelsman',
#   'parent_uuid': '753caedf8327429ae7038041172ba65a'},
#  {'uuid': 'd29368129c77b1230a326c9b9d0e70bd',
#   'title': 'Able Seaman',
#   'normalized_job_title': 'able seaman',
#   'parent_uuid': '753caedf8327429ae7038041172ba65a'},
#  {'uuid': '3278dab99f205e09fb62165770d0b8fa',
#   'title': 'Abnormal Psychology Teacher',
#   'normalized_job_title': 'abnormal psychology teacher',
#   'parent_uuid': '157d104fb9295abb821ff19f5a9f05ae'},
#  {'uuid': 'fecd3f1ac5091a6a0172454554d82ca9',
#   'title': 'Abrasive and Polished Products Supervisor',
#   'normalized_job_title': 'abrasive and polished products supervisor',
#   'parent_uuid': 'd72271093395fd0e5f645037b6b68e70'},
#  {'uuid': '5cf7e220b9298039795bbe46640689a2',
#   'title': 'Abrasive Band Winder',
#   'normalized_job_title': 'abrasive band winder',
#   'parent_uuid': 'd8a6bdc826f7520bfb69106843bd691b'},
#  {'uuid': 'e91d554624a62ad6a6b1373c8769fdae',
#   'title': 'Abrasive Coating Machine Operator',
#   'normalized_job_title': 'abrasive coating machine operator',
#   'parent_uuid': '12e070d50f4e84afba9e0b51a60ff517'},
#  {'uuid': 'd6b07a18da766dac94389ff90f5d17a7',
#   'title': 'Abrasive Coating Machine Set Up Operator',
#   'normalized_job_title': 'abrasive coating machine set up operator',
#   'parent_uuid': '12e070d50f4e84afba9e0b51a60ff517'},
#  {'uuid': 'c55b9469b0074c6ac3cec8b50ecbe9fc',
#   'title': 'Abrasive Grader',
#   'normalized_job_title': 'abrasive grader',
#   'parent_uuid': 'cbf98e104e5cea3f42d1d33f6ce11942'},
#  {'uuid': 'f438a14b8e4a7eb4d02d106430cfd1c3',
#   'title': 'Abrasive Grader Helper',
#   'normalized_job_title': 'abrasive grader helper',
#   'parent_uuid': '306db1c7b107844442875474968a66ed'},
#  {'uuid': 'a273e31490e26ca3c835957b89d48275',
#   'title': 'Abrasive Grinder',
#   'normalized_job_title': 'abrasive grinder',
#   'parent_uuid': '94c7b8b8276fa061eac26004a324934b'},
#  {'uuid': '95d2336f137d4d64df024120bc241c63',
#   'title': 'Abrasive Mixer',
#   'normalized_job_title': 'abrasive mixer',
#   'parent_uuid': '27cf2226730aca9526eac4e00696642a'},
#  {'uuid': 'ee8ea8da63ecfb70ebfb98f1d1021c0b',
#   'title': 'Abrasive Mixer Helper',
#   'normalized_job_title': 'abrasive mixer helper',
#   'parent_uuid': 'e3f3244ad58f52589c7f42d636884892'},
#  {'uuid': '40a194de34171813c5bd96a9299539c4',
#   'title': 'Abrasive Sawyer',
#   'normalized_job_title': 'abrasive sawyer',
#   'parent_uuid': '04621e69962dba38af33388bf6982731'},
#  {'uuid': '03343b8255529c48cfa93d22ddc69274',
#   'title': 'Abrasives Sales Representative',
#   'normalized_job_title': 'abrasives sales representative',
#   'parent_uuid': '6e9b18eea207f589c25dbfbf73c021b2'},
#  {'uuid': '6d89e84880fa6d04838add65544f42d8',
#   'title': 'Abrasive Wheel Molder',
#   'normalized_job_title': 'abrasive wheel molder',
#   'parent_uuid': 'd164f99f83321a11be7955bf9a1ac98d'},
#  {'uuid': '141cfa8d30975f5888f34ec8fa6f081b',
#   'title': 'Abrasive Worker',
#   'normalized_job_title': 'abrasive worker',
#   'parent_uuid': '876182c088ff798ff7b7734572e2ce06'},
#  {'uuid': '7f3c9cb15d4feae3fdaa4d9cddd8ab39',
#   'title': 'Absorber Operator',
#   'normalized_job_title': 'absorber operator',
#   'parent_uuid': '330ee83b06ca2c6a1f1aea07d6fde34f'},
#  {'uuid': '6db3f5e240810d705184eb5ea78f9beb',
#   'title': 'Absorption and Adsorption Engineer',
#   'normalized_job_title': 'absorption and adsorption engineer',
#   'parent_uuid': '43b10484b2a8474bbeadf9e4b2464fb5'},
#  {'uuid': '41f664e0cc43d317370d0b9334214bb3',
#   'title': 'Absorption Operator',
#   'normalized_job_title': 'absorption operator',
#   'parent_uuid': '330ee83b06ca2c6a1f1aea07d6fde34f'},
#  {'uuid': 'fcfb005c23c75b07c18f841b2faaf00c',
#   'title': 'Absorption Plant Operator',
#   'normalized_job_title': 'absorption plant operator',
#   'parent_uuid': '45e0754b3065fb24d04af08fb26e7752'},
#  {'uuid': '6aa0f2249c89e5a4a657f442e4ac45a2',
#   'title': 'Abstract Clerk',
#   'normalized_job_title': 'abstract clerk',
#   'parent_uuid': '5664385a36b9a0aa6f63c498e86b4654'},
#  {'uuid': 'b0cdb547ce143cc9c1c788b263011e37',
#   'title': 'Abstracter',
#   'normalized_job_title': 'abstracter',
#   'parent_uuid': '5664385a36b9a0aa6f63c498e86b4654'},
#  {'uuid': '9193cf1de6353132b5a0545058744f3f',
#   'title': 'Abstract Searcher',
#   'normalized_job_title': 'abstract searcher',
#   'parent_uuid': '5664385a36b9a0aa6f63c498e86b4654'},
#  {'uuid': 'af8425eb2053b678237f6f61d689d43a',
#   'title': 'Abstract Writer',
#   'normalized_job_title': 'abstract writer',
#   'parent_uuid': '5664385a36b9a0aa6f63c498e86b4654'},
#  {'uuid': '57c71df8ea40de263a4329ceb7220056',
#   'title': 'Academic Advisement Director',
#   'normalized_job_title': 'academic advisement director',
#   'parent_uuid': 'a2995c6d482fe453de5f2d7707af44d1'},
#  {'uuid': 'bd3ef7ceddb03f8c190a25b0fc167f71',
#   'title': 'Academic Adviser',
#   'normalized_job_title': 'academic adviser',
#   'parent_uuid': 'a2995c6d482fe453de5f2d7707af44d1'},
#  {'uuid': 'e527926d0504bffa594714208b9065a3',
#   'title': 'Academic Advising Director',
#   'normalized_job_title': 'academic advising director',
#   'parent_uuid': 'a2995c6d482fe453de5f2d7707af44d1'},
#  {'uuid': '1f2e10e507433d01ec75c2c95fb8b7aa',
#   'title': 'Academic Advisor',
#   'normalized_job_title': 'academic advisor',
#   'parent_uuid': 'a2995c6d482fe453de5f2d7707af44d1'},
#  {'uuid': '2c6915647ce2f550e1b0800bb1cd68c9',
#   'title': 'Academic Affairs Dean',
#   'normalized_job_title': 'academic affairs dean',
#   'parent_uuid': '6f733093f5064e537eff0c4db1288492'},
#  {'uuid': '5ecb9cf1af11d62780c4533e9577233c',
#   'title': 'Academic Affairs Director',
#   'normalized_job_title': 'academic affairs director',
#   'parent_uuid': '6f733093f5064e537eff0c4db1288492'},
#  {'uuid': '3a489914db4656c59031cb6dd91d00df',
#   'title': 'Academic Affairs Vice President',
#   'normalized_job_title': 'academic affairs vice president',
#   'parent_uuid': '6f733093f5064e537eff0c4db1288492'},
#  {'uuid': 'f352d2754db33111a94c28c5bd83b6aa',
#   'title': 'Academic Computing Director',
#   'normalized_job_title': 'academic computing director',
#   'parent_uuid': '974d3fb78b871ead158cf91bfdd2e1b2'},
#  {'uuid': '2f4f1021f1b8cc410b7001fbd5546ea7',
#   'title': 'Academic Coordinator',
#   'normalized_job_title': 'academic coordinator',
#   'parent_uuid': 'a2995c6d482fe453de5f2d7707af44d1'},
#  {'uuid': '570b580856da9aa39451adf6a3359c2f',
#   'title': 'Academic Counselor',
#   'normalized_job_title': 'academic counselor',
#   'parent_uuid': 'a2995c6d482fe453de5f2d7707af44d1'},
#  {'uuid': 'ac0c36c2b8e8c6b4dc5956c5709655af',
#   'title': 'Academic Dean',
#   'normalized_job_title': 'academic dean',
#   'parent_uuid': '6f733093f5064e537eff0c4db1288492'},
#  {'uuid': '4d61da9a1f603b50a51bdc8cac0355e6',
#   'title': 'Academic Department Chair',
#   'normalized_job_title': 'academic department chair',
#   'parent_uuid': '6f733093f5064e537eff0c4db1288492'},
#  {'uuid': '251c0b94c6368a4611cbf9fb77803bcf',
#   'title': 'Academic Director',
#   'normalized_job_title': 'academic director',
#   'parent_uuid': '6f733093f5064e537eff0c4db1288492'},
#  {'uuid': '56621fabb0d720b0c54dcca4dc3749a3',
#   'title': 'Academic Guidance Specialist',
#   'normalized_job_title': 'academic guidance specialist',
#   'parent_uuid': '620195c432b4b7f5c99d8eb8c1c8d3a6'},
#  {'uuid': '0a1b378d2af1b3a986e5bc5473a8834d',
#   'title': 'Academic Hospitalist',
#   'normalized_job_title': 'academic hospitalist',
#   'parent_uuid': 'c8f6fb6fa6aa2834662765d348e71352'},
#  {'uuid': '78374bf4449a1dd1b4f16ac34a1885df',
#   'title': 'Academic Interventionist',
#   'normalized_job_title': 'academic interventionist',
#   'parent_uuid': '7f8ab1917158c5fbffe83402e8cbebb7'},
#  {'uuid': 'f07d0d85fdebebc6d0fffe1fcca54708',
#   'title': 'Academic Support Center Director',
#   'normalized_job_title': 'academic support center director',
#   'parent_uuid': '1407f44eab489a942df80658db0cfccc'},
#  {'uuid': 'ba0d5950a2419e6ebe935fc3b00ac161',
#   'title': 'Academic Support Director',
#   'normalized_job_title': 'academic support director',
#   'parent_uuid': '6f733093f5064e537eff0c4db1288492'},
#  {'uuid': '9c6c5d10b1dc4b4ca7b7fe2863357f68',
#   'title': 'Academic Tutor',
#   'normalized_job_title': 'academic tutor',
#   'parent_uuid': '620195c432b4b7f5c99d8eb8c1c8d3a6'},
#  {'uuid': '59a36acac2020266efb23fb4ab3c2b70',
#   'title': 'Academic Vice President',
#   'normalized_job_title': 'academic vice president',
#   'parent_uuid': '6f733093f5064e537eff0c4db1288492'},
#  {'uuid': 'da7cfdc4bb6423b9bb1c8777a23922e0',
#   'title': 'Accelerator Operator',
#   'normalized_job_title': 'accelerator operator',
#   'parent_uuid': '8908a580adb429c507e29b07a6d9c5bc'},
#  {'uuid': '4a70f5bdcf21446cab948f7df4a9986d',
#   'title': 'Accelerator Systems Director',
#   'normalized_job_title': 'accelerator systems director',
#   'parent_uuid': '6c8aa632d45cf314e8ec807a039bf149'},
#  {'uuid': '1c8e7439cb7e4bd88d2819b2426b84cf',
#   'title': 'Accelerator Technician',
#   'normalized_job_title': 'accelerator technician',
#   'parent_uuid': '8908a580adb429c507e29b07a6d9c5bc'},
#  {'uuid': '70c9bc0a60716803e80b31f602223081',
#   'title': 'Access Control Officer',
#   'normalized_job_title': 'access control officer',
#   'parent_uuid': '7462741af8b35916f28a8a125427bc7a'},
#  {'uuid': '6796e627e2d54091c6335adb47d66d85',
#   'title': 'Access Control Specialist',
#   'normalized_job_title': 'access control specialist',
#   'parent_uuid': 'fed92aac07a35924430a0b4212dad53f'},
#  {'uuid': 'f3c8d9cdf3efbce81c6af68996e8e1b5',
#   'title': 'Access Coordinator',
#   'normalized_job_title': 'access coordinator',
#   'parent_uuid': '56c2b37e8af5f0a7d99aa7388eee7cc9'},
#  {'uuid': 'cb0f164f9250020179d7bafa9cee75dd',
#   'title': 'Accessibility Lift Technician',
#   'normalized_job_title': 'accessibility lift technician',
#   'parent_uuid': '7bc8605ff5e6f9ba23815742be285fd4'},
#  {'uuid': 'f331049c18123f19dc65b07f46e22bf6',
#   'title': 'Accessioner',
#   'normalized_job_title': 'accessioner',
#   'parent_uuid': '340ba58cc336fee4e3120d2a1a09b26b'},
#  {'uuid': '3b388ccc6091b6af5d2b49815100152a',
#   'title': 'Access Services Assistant',
#   'normalized_job_title': 'access services assistant',
#   'parent_uuid': 'b30370f068a350a30c1095becb75707a'},
#  {'uuid': '820f66e5959b22d4c15772a3bf878e31',
#   'title': 'Access Services Librarian',
#   'normalized_job_title': 'access services librarian',
#   'parent_uuid': 'dbbb1aac7a8350963ce0295efb70ae81'},
#  {'uuid': '91c1a01ef7649bb50336ec434cc1363c',
#   'title': 'Accident Examiner',
#   'normalized_job_title': 'accident examiner',
#   'parent_uuid': 'c7c87829ec3043862566c020d424c1a8'},
#  {'uuid': 'e6ae24cd0e6cba58afb5c4a83356c50d',
#   'title': 'Accident Investigator',
#   'normalized_job_title': 'accident investigator',
#   'parent_uuid': 'c7c87829ec3043862566c020d424c1a8'},
#  {'uuid': '1cd9663d9e3b201ee0980c084ba51ac6',
#   'title': 'Accident Prevention Squad Police Officer',
#   'normalized_job_title': 'accident prevention squad police officer',
#   'parent_uuid': 'e78bc4a44da24907351e64a19580c933'},
#  {'uuid': 'b9b41b954229c7a83b63401711e26b69',
#   'title': 'Accompanist',
#   'normalized_job_title': 'accompanist',
#   'parent_uuid': 'de4684389978230e3c916f74dbcde1b2'},
#  {'uuid': '938018d26e99841acc4cc4ed52db1d5e',
#   'title': 'Accordion Maker',
#   'normalized_job_title': 'accordion maker',
#   'parent_uuid': '0088cdefc030332fa0f4a7f74c42da3e'},
#  {'uuid': 'f83f5c506f4b62c88ab224ab9f856ec2',
#   'title': 'Accordion Repairer',
#   'normalized_job_title': 'accordion repairer',
#   'parent_uuid': 'af5a7c9298e2bed61fd7aa88749463a3'},
#  {'uuid': '0da96d90d33247bd4609325e4c430d7e',
#   'title': 'Accordion Tuner',
#   'normalized_job_title': 'accordion tuner',
#   'parent_uuid': 'af5a7c9298e2bed61fd7aa88749463a3'},
#  {'uuid': '05e6ca2db4bf98acd6a11d994f5ab90b',
#   'title': 'Accountable Clerk',
#   'normalized_job_title': 'accountable clerk',
#   'parent_uuid': 'ff281d7eb01f4dba07337d20aebff7f5'},
#  {'uuid': '81e6d6a75bf7fd5cd96309a5e6c2b780',
#   'title': 'Account Adjuster',
#   'normalized_job_title': 'account adjuster',
#   'parent_uuid': '706b0d4ce27d6840a7d69ce4bd1e212b'},
#  {'uuid': '8c3d2ea49751e2aea595468c948b11c2',
#   'title': 'Account Administrator',
#   'normalized_job_title': 'account administrator',
#   'parent_uuid': '03497acd5004c8fb10ac07c6663d1e72'},
#  {'uuid': '0bee5475ad46c41952ac2eb0a7012ee7',
#   'title': 'Account Analyst',
#   'normalized_job_title': 'account analyst',
#   'parent_uuid': '344aba9dcfa11889b5ae926bfab624e8'},
#  {'uuid': 'a1307bdaa04999057b86128944fdbbbf',
#   'title': 'Accountancy Professor',
#   'normalized_job_title': 'accountancy professor',
#   'parent_uuid': '9783ebd146cb9e0b64d51cc168b20010'},
#  {'uuid': '7516132c51e75ce65534cbdcc96c2c45',
#   'title': 'Accountant',
#   'normalized_job_title': 'accountant',
#   'parent_uuid': '30ea61559d05eaa71e684f6e350494b1'},
#  {'uuid': 'e56c6c85643e652d6ae8e51edf874b58',
#   'title': 'Accountant Assistant',
#   'normalized_job_title': 'accountant assistant',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': 'b72ed67875adc71a1b2024b7158fe9f5',
#   'title': 'Accountant Clerk',
#   'normalized_job_title': 'accountant clerk',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': '55e79595a910c3213dc564f7fa126723',
#   'title': 'Accountant Helper',
#   'normalized_job_title': 'accountant helper',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': 'd825d16c0a9924db4ca7d31e3b63bab9',
#   'title': 'Accountant Manager',
#   'normalized_job_title': 'accountant manager',
#   'parent_uuid': '30ea61559d05eaa71e684f6e350494b1'},
#  {'uuid': 'dc6e82eeac30a649b704798d093c1d2e',
#   'title': 'Accountant Supervisor',
#   'normalized_job_title': 'accountant supervisor',
#   'parent_uuid': 'a0cc5b003799d172211c33a9c14929dc'},
#  {'uuid': '49ca7987017b6b56c73f9259142af6c7',
#   'title': 'Account Auditor',
#   'normalized_job_title': 'account auditor',
#   'parent_uuid': '30ab203f437e940183274ac15379aa99'},
#  {'uuid': '61cfea2e063567cb16ca2a18c96df5e8',
#   'title': 'Account Clerk',
#   'normalized_job_title': 'account clerk',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': 'd2c468aa4044268d36b8da1383964225',
#   'title': 'Account Development Manager',
#   'normalized_job_title': 'account development manager',
#   'parent_uuid': '6e9b18eea207f589c25dbfbf73c021b2'},
#  {'uuid': '6fce9c675b516bdc5894dbafdb1c2adc',
#   'title': 'Account Director',
#   'normalized_job_title': 'account director',
#   'parent_uuid': '09ceac85294edf92c92c68971a09c905'},
#  {'uuid': 'af9afdc6bb8ed4ba241b43afe0ed8e1a',
#   'title': 'Account Executive',
#   'normalized_job_title': 'account executive',
#   'parent_uuid': '1458f7aba7fa08b3920d2836d95ce518'},
#  {'uuid': '44a8d0d94f57553b3f73fcc7741590d5',
#   'title': 'Account Executive, Key Accounts',
#   'normalized_job_title': 'account executive key accounts',
#   'parent_uuid': '4aaf1c1eb45dfbec87b7fc2dc5f088a2'},
#  {'uuid': '5036224dc0a7baaac875cf371a8a1978',
#   'title': 'Account Information Clerk',
#   'normalized_job_title': 'account information clerk',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': '6fa3038c0ed8130876789ce8ea30f482',
#   'title': 'Accounting Administrator',
#   'normalized_job_title': 'accounting administrator',
#   'parent_uuid': '3ffe9bc56a3fd00b02fbdc71c03976f9'},
#  {'uuid': 'c2c7e1fb595982718dcb6656a7065642',
#   'title': 'Accounting Analyst',
#   'normalized_job_title': 'accounting analyst',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': '9fc25ecc1f5d511393500b94bf089780',
#   'title': 'Accounting Assistant',
#   'normalized_job_title': 'accounting assistant',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': '4930c5fada61e91e22626e5145055a4b',
#   'title': 'Accounting Associate',
#   'normalized_job_title': 'accounting associate',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': 'bb4b904b7e40d0e965d1ad160aa80e1d',
#   'title': 'Accounting Auditor',
#   'normalized_job_title': 'accounting auditor',
#   'parent_uuid': '30ab203f437e940183274ac15379aa99'},
#  {'uuid': '9cc4712b2d92780558c8e734a0f1ce6b',
#   'title': 'Accounting Bookkeeper',
#   'normalized_job_title': 'accounting bookkeeper',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': '6cd56a634d983fd19131dbacad75f45a',
#   'title': 'Accounting Clerk',
#   'normalized_job_title': 'accounting clerk',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': '655022b35aa64ba44f4e798a6cb98ea3',
#   'title': 'Accounting Clerks Supervisor',
#   'normalized_job_title': 'accounting clerks supervisor',
#   'parent_uuid': '3ffe9bc56a3fd00b02fbdc71c03976f9'},
#  {'uuid': 'a7dba2d47762f45d6e7abf86012f01e3',
#   'title': 'Accounting Consultant',
#   'normalized_job_title': 'accounting consultant',
#   'parent_uuid': '30ea61559d05eaa71e684f6e350494b1'},
#  {'uuid': 'e2a82439cbeef272b48583766b5da513',
#   'title': 'Accounting Coordinator',
#   'normalized_job_title': 'accounting coordinator',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': 'd054b8fe6b6b17b00adc808242ef79f8',
#   'title': 'Accounting Director',
#   'normalized_job_title': 'accounting director',
#   'parent_uuid': '3ffe9bc56a3fd00b02fbdc71c03976f9'},
#  {'uuid': 'a027b8edcf50b5da8540f73111390490',
#   'title': 'Accounting/Finance Tutor',
#   'normalized_job_title': 'accountingfinance tutor',
#   'parent_uuid': '620195c432b4b7f5c99d8eb8c1c8d3a6'},
#  {'uuid': 'f43f64f9544379a7069ac500f8671b56',
#   'title': 'Accounting Instructor',
#   'normalized_job_title': 'accounting instructor',
#   'parent_uuid': '5b42002f42413293153a7081e7356a4a'},
#  {'uuid': 'b735a9bd550a36562dd4e6feae51d117',
#   'title': 'Accounting Lecturer',
#   'normalized_job_title': 'accounting lecturer',
#   'parent_uuid': '9783ebd146cb9e0b64d51cc168b20010'},
#  {'uuid': '18cfdd27ad3a1050109eab4587b6adec',
#   'title': 'Accounting Machine Mechanic',
#   'normalized_job_title': 'accounting machine mechanic',
#   'parent_uuid': '9bc8ed0e7fbe7a61815cdced4cb639c7'},
#  {'uuid': '35a2abeacc2737442083f3dfb84af50a',
#   'title': 'Accounting Machine Operator',
#   'normalized_job_title': 'accounting machine operator',
#   'parent_uuid': '0637a769b083f40cd9d36512642da3e5'},
#  {'uuid': '01f4d907e83e411c982303db2b449f14',
#   'title': 'Accounting Manager',
#   'normalized_job_title': 'accounting manager',
#   'parent_uuid': '3ffe9bc56a3fd00b02fbdc71c03976f9'},
#  {'uuid': 'c17da3261af1e033fc216d53adabd943',
#   'title': 'Accounting Methods Analyst',
#   'normalized_job_title': 'accounting methods analyst',
#   'parent_uuid': '30ea61559d05eaa71e684f6e350494b1'},
#  {'uuid': '5fbe08bcaa83751b80e2e64ed5bf5e73',
#   'title': 'Accounting Officer',
#   'normalized_job_title': 'accounting officer',
#   'parent_uuid': '30ea61559d05eaa71e684f6e350494b1'},
#  {'uuid': '90812450381bf2e3b9cb810a81c420f4',
#   'title': 'Accounting Professor',
#   'normalized_job_title': 'accounting professor',
#   'parent_uuid': '9783ebd146cb9e0b64d51cc168b20010'},
#  {'uuid': 'f82a2e58444a16d1b7da2fb1a60e37df',
#   'title': 'Accounting Representative',
#   'normalized_job_title': 'accounting representative',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': '635d4c2845996ec9fede9dfe3cd7a3dc',
#   'title': 'Accounting Specialist',
#   'normalized_job_title': 'accounting specialist',
#   'parent_uuid': '8ab342c81b400740d83e06d1a10b6066'},
#  {'uuid': 'ac87a0b5f52d967b0a2a837b74b3c4bc',
#   'title': 'Accounting Supervisor',
#   'normalized_job_title': 'accounting supervisor',
#   'parent_uuid': '082d8c7fd1f72dfd5027839655ee4b18'},
#  {'uuid': '1d6f991b537be205330013b48846d3de',
#   'title': 'Accounting Systems Analyst',
#   'normalized_job_title': 'accounting systems analyst',
#   'parent_uuid': '30ea61559d05eaa71e684f6e350494b1'},
#  {'uuid': '947f996185f4c44605659e3e979c784c',
#   'title': 'Accounting Teacher',
#   'normalized_job_title': 'accounting teacher',
#   'parent_uuid': '74004ab17f97a04d666a3f3ea09a4fb4'},
#  {'uuid': 'e93fe4825ba607c3742ded603685c9a4',
#   'title': 'Accounting Technician',
#   'normalized_job_title': 'accounting technician',
#   'parent_uuid': '8ab342c81b400740d83e06d1a10b6066'},
#  {'uuid': 'c2edfa2b4f7712519915efb280104975',
#   'title': 'Account Leader',
#   'normalized_job_title': 'account leader',
#   'parent_uuid': '1458f7aba7fa08b3920d2836d95ce518'},
#  {'uuid': '67929a59f2f08a70120f544ac56b0e70',
#   'title': 'Account Manager',
#   'normalized_job_title': 'account manager',
#   'parent_uuid': '03497acd5004c8fb10ac07c6663d1e72'},
#  {'uuid': '49afa941993999cdda889745a4fce3d8',
#   'title': 'Account Manager (Salesman)',
#   'normalized_job_title': 'account manager salesman',
#   'parent_uuid': '4aaf1c1eb45dfbec87b7fc2dc5f088a2'},
#  {'uuid': 'a7965767c08fd6046972fbd1e50879b3',
#   'title': 'Account Receivable Associate',
#   'normalized_job_title': 'account receivable associate',
#   'parent_uuid': 'dec033a612a61b78855f2197e3b7a695'},
#  {'uuid': '11cb0fab2e6a4724d8dbb7d298387db2',
#   'title': 'Account Receivable Clerk',
#   'normalized_job_title': 'account receivable clerk',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': '7f5190b3c4a3dc689762c55e24d50d56',
#   'title': 'Account Representative',
#   'normalized_job_title': 'account representative',
#   'parent_uuid': '706b0d4ce27d6840a7d69ce4bd1e212b'},
#  {'uuid': 'f630d013c74dfe885f635de3964ad05e',
#   'title': 'Account Representative-Non-Profit Division',
#   'normalized_job_title': 'account representativenonprofit division',
#   'parent_uuid': '9d1794e59aa96e732a9021bd1a80e9f5'},
#  {'uuid': 'cd98e0965bf3218847da02c51e26d593',
#   'title': 'Account Resolution Analyst',
#   'normalized_job_title': 'account resolution analyst',
#   'parent_uuid': 'dec033a612a61b78855f2197e3b7a695'},
#  {'uuid': 'b2fe3d3aa3f94e7c03394179c811541b',
#   'title': 'Accounts Adjustable Clerk',
#   'normalized_job_title': 'accounts adjustable clerk',
#   'parent_uuid': '0637a769b083f40cd9d36512642da3e5'},
#  {'uuid': 'a2e1f5063c6effd34decc9eab8e6e2fc',
#   'title': 'Accounts Collector',
#   'normalized_job_title': 'accounts collector',
#   'parent_uuid': 'dec033a612a61b78855f2197e3b7a695'},
#  {'uuid': '205cfcf1961b7558aa98f3f80a7bc2c5',
#   'title': 'Account Service Representative',
#   'normalized_job_title': 'account service representative',
#   'parent_uuid': 'dec033a612a61b78855f2197e3b7a695'},
#  {'uuid': 'b03e4aa1810e91bd5aa7997d4adb6ef4',
#   'title': 'Account Services Representative',
#   'normalized_job_title': 'account services representative',
#   'parent_uuid': '344aba9dcfa11889b5ae926bfab624e8'},
#  {'uuid': '1ed0dcd04522999653c448ee83deb97a',
#   'title': 'Accounts Executive',
#   'normalized_job_title': 'accounts executive',
#   'parent_uuid': '1458f7aba7fa08b3920d2836d95ce518'},
#  {'uuid': '09b51a190d2451726eabc1294a1e9fca',
#   'title': 'Accounts Manager',
#   'normalized_job_title': 'accounts manager',
#   'parent_uuid': '9db00d72807fa7ff5d56a96e6fc7d2d8'},
#  {'uuid': '5579403c347cfbb9798a1056e9e8fb4f',
#   'title': 'Accounts Payable Administrator',
#   'normalized_job_title': 'accounts payable administrator',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': '3c68d263621f63df37742f1733044098',
#   'title': 'Accounts Payable Associate',
#   'normalized_job_title': 'accounts payable associate',
#   'parent_uuid': '0637a769b083f40cd9d36512642da3e5'},
#  {'uuid': '393267f459a5146a67598af2136c2c60',
#   'title': 'Accounts Payable Clerk',
#   'normalized_job_title': 'accounts payable clerk',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': '3d2cccdfb4ff86faa52d874c67974a0a',
#   'title': 'Accounts Payable Coordinator',
#   'normalized_job_title': 'accounts payable coordinator',
#   'parent_uuid': '0637a769b083f40cd9d36512642da3e5'},
#  {'uuid': '35d0c62a29f54c1e663e5481c48c2099',
#   'title': 'Accounts Payable Manager',
#   'normalized_job_title': 'accounts payable manager',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': 'c344dc71925bb3d1ebaa04552ae2d2d9',
#   'title': 'Accounts Payable Representative',
#   'normalized_job_title': 'accounts payable representative',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': 'e77558b2902273ef18659ec0ff87e2c8',
#   'title': 'Accounts Payables Clerk',
#   'normalized_job_title': 'accounts payables clerk',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': '82472e8a286abc12b224cf10f3e8cd28',
#   'title': 'Accounts Payable Specialist',
#   'normalized_job_title': 'accounts payable specialist',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': 'aa7d708c0a02f03cd478cc7f0a084e41',
#   'title': 'Accounts Payable Supervisor',
#   'normalized_job_title': 'accounts payable supervisor',
#   'parent_uuid': '3ffe9bc56a3fd00b02fbdc71c03976f9'},
#  {'uuid': 'c73029709e7704450a16b4c2655c010d',
#   'title': 'Account Specialist',
#   'normalized_job_title': 'account specialist',
#   'parent_uuid': '4aaf1c1eb45dfbec87b7fc2dc5f088a2'},
#  {'uuid': 'a87472ac1daf3db916f0a4e4ac567650',
#   'title': 'Accounts Receivable Assistant',
#   'normalized_job_title': 'accounts receivable assistant',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': 'c1329280e6e6fcca3feb72ddf9d29ded',
#   'title': 'Accounts Receivable Clerk',
#   'normalized_job_title': 'accounts receivable clerk',
#   'parent_uuid': '3eb8be26f38d699304907a67cf4e8cd8'},
#  {'uuid': 'c6e470253e53b7909de3e899eacdd16d',
#   'title': 'Accounts Receivable Coordinater',
#   'normalized_job_title': 'accounts receivable coordinater',
#   'parent_uuid': '0637a769b083f40cd9d36512642da3e5'},
#  {'uuid': '5a95a37febe7ebea9316f600021d5c6b',
#   'title': 'Accounts Receivable Manager',
#   'normalized_job_title': 'accounts receivable manager',
#   'parent_uuid': '3ffe9bc56a3fd00b02fbdc71c03976f9'},
#  {'uuid': '5bd7dd210fc79907ce7edd38b3292bd9',
#   'title': 'Accounts Receivable Specialist',
#   'normalized_job_title': 'accounts receivable specialist',
#   'parent_uuid': 'dec033a612a61b78855f2197e3b7a695'},
#  {'uuid': '60522c66ee614bcde8d5716ebca91b6d',
#   'title': 'Accounts Receivable Supervisor',
#   'normalized_job_title': 'accounts receivable supervisor',
#   'parent_uuid': '3ffe9bc56a3fd00b02fbdc71c03976f9'},
#  {'uuid': '708365b4ca12aacfa85bc180c821f1f4',
#   'title': 'Accounts Supervisor',
#   'normalized_job_title': 'accounts supervisor',
#   'parent_uuid': 'a0cc5b003799d172211c33a9c14929dc'},
#  {'uuid': '74f93e6634e302c247588b2590e244c7',
#   'title': 'Account Supervisor',
#   'normalized_job_title': 'account supervisor',
#   'parent_uuid': 'd2ed4377484aba967ddc637246afc44c'},
#  {'uuid': 'b80e2a80f09c2ae6e7b86750474a29e1',
#   'title': 'Account Underwriter',
#   'normalized_job_title': 'account underwriter',
#   'parent_uuid': '5bea6020695f4e29ccfffec048099344'},
#  {'uuid': 'c87ced5cfd60201c07670b064b251e2f',
#   'title': 'Accredited Farm Manager (AFM)',
#   'normalized_job_title': 'accredited farm manager afm',
#   'parent_uuid': '09ee343efed5751cb9963217ad2e423e'},
#  {'uuid': 'e8a664bbf985d1735c0a59220d25d853',
#   'title': 'Accredited Legal Secretary',
#   'normalized_job_title': 'accredited legal secretary',
#   'parent_uuid': '8aeee194a0e709e0c555aab374ac7c3a'},
#  {'uuid': 'a89d21dfdddc623f76a13a05f3b1b6c5',
#   'title': 'Accredited Pharmacy Technician',
#   'normalized_job_title': 'accredited pharmacy technician',
#   'parent_uuid': 'e911da08f4dde94eb879e25cb1584d8c'},
#  {'uuid': 'd92b372cca300504ecdf1bb1dc04f1ef',
#   'title': 'Accuracy Expert',
#   'normalized_job_title': 'accuracy expert',
#   'parent_uuid': 'fcfdb76b27a6e4c34abd128cbd9f61ba'},
#  {'uuid': '657677ec31c06e8c9f998700795b3a5f',
#   'title': 'AC/DC Motor Repair Person',
#   'normalized_job_title': 'acdc motor repair person',
#   'parent_uuid': 'f5227b65ca90a183fb3ca86377a5efa4'},
#  {'uuid': '9ac3cd678550253f8266eb106cbad882',
#   'title': 'AC/DC Rewinder',
#   'normalized_job_title': 'acdc rewinder',
#   'parent_uuid': 'f5227b65ca90a183fb3ca86377a5efa4'},
#  {'uuid': '1d6e7419e464e8cd7ed8fa90a42bcb9c',
#   'title': 'AC/DC Winder',
#   'normalized_job_title': 'acdc winder',
#   'parent_uuid': 'f5227b65ca90a183fb3ca86377a5efa4'},
#  {'uuid': '7525755ca9f8d0e8667676e5a51ce154',
#   'title': 'Acds Block 1 Operator',
#   'normalized_job_title': 'acds block 1 operator',
#   'parent_uuid': '6f9149ac366ff781e9850650a6d61e80'},
#  {'uuid': '5f7d26f2b04cdd8ea4a41dddfd518299',
#   'title': 'Acetone Button Paster',
#   'normalized_job_title': 'acetone button paster',
#   'parent_uuid': 'd8a6bdc826f7520bfb69106843bd691b'},
#  {'uuid': '2dcff6af11454efc93ca6619621c8fe4',
#   'title': 'Acetone Recovery Worker',
#   'normalized_job_title': 'acetone recovery worker',
#   'parent_uuid': '330ee83b06ca2c6a1f1aea07d6fde34f'},
#  {'uuid': 'ef5067fa4996272d2319aeba41ab2fba',
#   'title': 'Acetylene Burner',
#   'normalized_job_title': 'acetylene burner',
#   'parent_uuid': '5e2e12def94dfc7f209137d8cc86c481'},
#  {'uuid': 'c708f9079eba04a77e8c95a5cdbf0f17',
#   'title': 'Acetylene Cutter',
#   'normalized_job_title': 'acetylene cutter',
#   'parent_uuid': '49a7ca68242e9a9a818a74d555fb834c'},
#  {'uuid': 'fcf4da7a83d8571c20bdba72188639be',
#   'title': 'Acetylene Cylinder Packing Mixer',
#   'normalized_job_title': 'acetylene cylinder packing mixer',
#   'parent_uuid': '27cf2226730aca9526eac4e00696642a'},
#  {'uuid': 'e07b11bb1ad0d3e73177047b733c34b2',
#   'title': 'Acetylene Gas Compressor',
#   'normalized_job_title': 'acetylene gas compressor',
#   'parent_uuid': '103e8a2e4430f2e3b6be95932624dcba'},
#  {'uuid': '49e81354d05ba5ecbfe63e7be44d029d',
#   'title': 'Acetylene Operator',
#   'normalized_job_title': 'acetylene operator',
#   'parent_uuid': '5e2e12def94dfc7f209137d8cc86c481'},
#  {'uuid': 'd1ec507c65b16d2a5853c1c7a8c2df12',
#   'title': 'Acetylene Plant Operator',
#   'normalized_job_title': 'acetylene plant operator',
#   'parent_uuid': '330ee83b06ca2c6a1f1aea07d6fde34f'},
#  {'uuid': 'a905ae7d131b06fd923f8feedb66a0b2',
#   'title': 'Acetylene Plant Technician',
#   'normalized_job_title': 'acetylene plant technician',
#   'parent_uuid': '103e8a2e4430f2e3b6be95932624dcba'},
#  {'uuid': '752eb28b540cea47e0bc0359e9798df7',
#   'title': 'Acetylene Torch Burner',
#   'normalized_job_title': 'acetylene torch burner',
#   'parent_uuid': '49a7ca68242e9a9a818a74d555fb834c'},
#  {'uuid': 'becc9696e1faf7e2a68f0c6c0314e531',
#   'title': 'Acetylene Torch Operator',
#   'normalized_job_title': 'acetylene torch operator',
#   'parent_uuid': '5e2e12def94dfc7f209137d8cc86c481'},
#  {'uuid': '9d4b8a65c8dd104434e66157132da46e',
#   'title': 'Acetylene Torch Solderer',
#   'normalized_job_title': 'acetylene torch solderer',
#   'parent_uuid': '5e2e12def94dfc7f209137d8cc86c481'},
#  {'uuid': '2c4c04dd392054cbacfbd15984cc5ab1',
#   'title': 'Acid Adjuster',
#   'normalized_job_title': 'acid adjuster',
#   'parent_uuid': 'd8a6bdc826f7520bfb69106843bd691b'},
#  {'uuid': '0335488b8f783517ebac67f809a77b00',
#   'title': 'Acid Bleacher',
#   'normalized_job_title': 'acid bleacher',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': 'bf1e5e28878b5c81d561f005669ad86e',
#   'title': 'Acid Blower',
#   'normalized_job_title': 'acid blower',
#   'parent_uuid': '27cf2226730aca9526eac4e00696642a'},
#  {'uuid': 'b8408f07a83854bb5fee19bda8b0750a',
#   'title': 'Acid Cleaner',
#   'normalized_job_title': 'acid cleaner',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': '2f1479e962d32b87f6b52b3ff6dfce5b',
#   'title': 'Acid Concentrator',
#   'normalized_job_title': 'acid concentrator',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': 'ea71ed182465eb7c2d217ad215b648c9',
#   'title': 'Acid Condenser',
#   'normalized_job_title': 'acid condenser',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': 'c12c7063a6ddee604e95dfbe9cad0811',
#   'title': 'Acid Conditioning Worker',
#   'normalized_job_title': 'acid conditioning worker',
#   'parent_uuid': 'd8a6bdc826f7520bfb69106843bd691b'},
#  {'uuid': '7cb7a46a15d376136b5bb00357e3a1e2',
#   'title': 'Acid Crane Operator',
#   'normalized_job_title': 'acid crane operator',
#   'parent_uuid': '045d11c8f045f01fb08614f135e6157d'},
#  {'uuid': '0f2775b49ef5a29abfade94d5840b126',
#   'title': 'Acid Dipper',
#   'normalized_job_title': 'acid dipper',
#   'parent_uuid': 'b6c7e5dfd3dcc9268ba9e5de5824ed59'},
#  {'uuid': '864cf30f3152dd15ee9a2df68a0774e8',
#   'title': 'Acid Dumper',
#   'normalized_job_title': 'acid dumper',
#   'parent_uuid': '306db1c7b107844442875474968a66ed'},
#  {'uuid': 'ebf37744113438daae89ee8cdbcfea03',
#   'title': 'Acid Etch Operator',
#   'normalized_job_title': 'acid etch operator',
#   'parent_uuid': '2f2bb80a9aca2cf093b0321890fbaf0c'},
#  {'uuid': '8321177663b31fe327ca536d1e232c16',
#   'title': 'Acid Extractor',
#   'normalized_job_title': 'acid extractor',
#   'parent_uuid': '330ee83b06ca2c6a1f1aea07d6fde34f'},
#  {'uuid': '6ef5cb9e1b6a84a87870a17101c2e086',
#   'title': 'Acid Filler',
#   'normalized_job_title': 'acid filler',
#   'parent_uuid': 'd8a6bdc826f7520bfb69106843bd691b'},
#  {'uuid': '9a3893624f9329620472c27ba4623c77',
#   'title': 'Acidity Tester',
#   'normalized_job_title': 'acidity tester',
#   'parent_uuid': '2163b9b215293604fe12aad7e6e6cfb1'},
#  {'uuid': '4ce6c1a22dd4e688091d4978214d373f',
#   'title': 'Acidizer',
#   'normalized_job_title': 'acidizer',
#   'parent_uuid': 'ed78db6df476c5317a2ea12e049140a3'},
#  {'uuid': '773e563716625f15faa54b7783c20105',
#   'title': 'Acid Loader',
#   'normalized_job_title': 'acid loader',
#   'parent_uuid': 'ac81f6e77b23ccb7ec3359ae4b31a052'},
#  {'uuid': 'c2aecfdcc20830044dc41db9a76784f4',
#   'title': 'Acid Maker',
#   'normalized_job_title': 'acid maker',
#   'parent_uuid': '8a99d8ee0e8ef198c9365e7c25540f83'},
#  {'uuid': '50e3d25fabcaf1144e6f87274e24069b',
#   'title': 'Acid Mixer',
#   'normalized_job_title': 'acid mixer',
#   'parent_uuid': '27cf2226730aca9526eac4e00696642a'},
#  {'uuid': '5309136866b2b5ae7fdab643b8aa6ca2',
#   'title': 'Acid Operator',
#   'normalized_job_title': 'acid operator',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': '175ff6623edf9752229b88663ccc436c',
#   'title': 'Acid Painter',
#   'normalized_job_title': 'acid painter',
#   'parent_uuid': 'd8a6bdc826f7520bfb69106843bd691b'},
#  {'uuid': '68ffebc4d1ecbd692178e9d2cde7d1bf',
#   'title': 'Acid Patroller',
#   'normalized_job_title': 'acid patroller',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': 'aed31c0f18689f07972e557c468b3990',
#   'title': 'Acid Plant Helper',
#   'normalized_job_title': 'acid plant helper',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': 'b083fd0684d4dfb68ea5162b30afa554',
#   'title': 'Acid Polymerization Operator',
#   'normalized_job_title': 'acid polymerization operator',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': '54ac8a36e80ef4de8732e1c42b6c38cd',
#   'title': 'Acid Pump Operator',
#   'normalized_job_title': 'acid pump operator',
#   'parent_uuid': 'ac81f6e77b23ccb7ec3359ae4b31a052'},
#  {'uuid': '06ca9344cd75071f52d5feae06fb81b2',
#   'title': 'Acid Purification Equipment Operator',
#   'normalized_job_title': 'acid purification equipment operator',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': 'd6fa160a421a5cebfe9e16a90c9b9252',
#   'title': 'Acid Purifier',
#   'normalized_job_title': 'acid purifier',
#   'parent_uuid': '330ee83b06ca2c6a1f1aea07d6fde34f'},
#  {'uuid': '0750b531b7e5c23ee206340647bc150c',
#   'title': 'Acid Recovery Operator',
#   'normalized_job_title': 'acid recovery operator',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': 'a34eceded88a8c9c5150d56898479fd4',
#   'title': 'Acid Regenerator',
#   'normalized_job_title': 'acid regenerator',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': 'a0e1055a976b8278573db16c89598810',
#   'title': 'Acid Remover',
#   'normalized_job_title': 'acid remover',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': '546b131831a3ff46278c6167dc53a5dc',
#   'title': 'Acid Retort Operator',
#   'normalized_job_title': 'acid retort operator',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': 'ffba2c102060c72198f30f54311b3c17',
#   'title': 'Acid Splicer',
#   'normalized_job_title': 'acid splicer',
#   'parent_uuid': 'd8a6bdc826f7520bfb69106843bd691b'},
#  {'uuid': 'e65c3d6fbfdcfdaa34f64fc91e0bd2f7',
#   'title': 'Acid Supervisor',
#   'normalized_job_title': 'acid supervisor',
#   'parent_uuid': 'd72271093395fd0e5f645037b6b68e70'},
#  {'uuid': '92b9e984a88f7e0d31807a568b93db0c',
#   'title': 'Acid Tank Liner',
#   'normalized_job_title': 'acid tank liner',
#   'parent_uuid': 'e361bb1d997e4c215fd15c646be00112'},
#  {'uuid': '1b38ebe48430b5a8045daacedad60274',
#   'title': 'Acid Tender',
#   'normalized_job_title': 'acid tender',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': 'd9cb84c7ee390da42f2ddd58e643d103',
#   'title': 'Acid Tester',
#   'normalized_job_title': 'acid tester',
#   'parent_uuid': 'cbf98e104e5cea3f42d1d33f6ce11942'},
#  {'uuid': '3f0031b9d3d53cde17ed0e3144424f1d',
#   'title': 'Acid Treater',
#   'normalized_job_title': 'acid treater',
#   'parent_uuid': '8ce491d9a26c7060fe59a4fbe95981d4'},
#  {'uuid': '04b56f5b45f09f594203ee495307496c',
#   'title': 'A Class Lineman',
#   'normalized_job_title': 'a class lineman',
#   'parent_uuid': '4cffdc4c240a543c38141583744e42a3'},
#  {'uuid': '7fdeec37da5db1cdc5e81c41b59b65dc',
#   'title': 'Acme - Gridley Tool Setter',
#   'normalized_job_title': 'acme  gridley tool setter',
#   'parent_uuid': 'c245133226963e7c736cfe98aa02d4d3'},
#  {'uuid': '7e3920cb06f833bfe879e354c4583db7',
#   'title': 'Acoustical Carpenter',
#   'normalized_job_title': 'acoustical carpenter',
#   'parent_uuid': '1704b4b5daf8d75ad95a6946bb5a0ae7'},
#  {'uuid': '5741ac93ca906067e24f346a7766c62d',
#   'title': 'Acoustical Ceiling Installer',
#   'normalized_job_title': 'acoustical ceiling installer',
#   'parent_uuid': '1704b4b5daf8d75ad95a6946bb5a0ae7'},
#  {'uuid': '7c48b3432b5403bec4ae4de22da46b23',
#   'title': 'Acoustical Ceiling Mechanic',
#   'normalized_job_title': 'acoustical ceiling mechanic',
#   'parent_uuid': '1704b4b5daf8d75ad95a6946bb5a0ae7'},
#  {'uuid': '225fca9f7a9dfb3324564e3cb6b1a3c5',
#   'title': 'Acoustical Ceiling Technician',
#   'normalized_job_title': 'acoustical ceiling technician',
#   'parent_uuid': '1704b4b5daf8d75ad95a6946bb5a0ae7'},
#  {'uuid': '002fc9603b3c9057b8abd693a5481276',
#   'title': 'Acoustical Engineer',
#   'normalized_job_title': 'acoustical engineer',
#   'parent_uuid': 'bdbf30e95939c7ffd556f3a5a97fdcd7'},
#  {'uuid': '635b96a231bf8128d31eec814d0f2e31',
#   'title': 'Acoustical Installer',
#   'normalized_job_title': 'acoustical installer',
#   'parent_uuid': '39d2737be8f9a4d15655efd130946467'},
#  {'uuid': 'cc764ee7cee4ba64130262bf6a8bbb83',
#   'title': 'Acoustical Material Worker',
#   'normalized_job_title': 'acoustical material worker',
#   'parent_uuid': '39d2737be8f9a4d15655efd130946467'},
#  {'uuid': 'acca96587644057dfd186342c305367b',
#   'title': 'Acoustical Tile Carpenters Supervisor',
#   'normalized_job_title': 'acoustical tile carpenters supervisor',
#   'parent_uuid': 'dee8d76e8c2440c128508566e1c57ff3'},
#  {'uuid': 'be9b2c0223fe7968ee73e828a8095112',
#   'title': 'Acoustical Tile Drill Press Operator',
#   'normalized_job_title': 'acoustical tile drill press operator',
#   'parent_uuid': 'd8a6bdc826f7520bfb69106843bd691b'},
#  {'uuid': '1d3eb5b95b89a384662a064a8e97dd70',
#   'title': 'Acoustical Tile Patternmaker',
#   'normalized_job_title': 'acoustical tile patternmaker',
#   'parent_uuid': 'd164f99f83321a11be7955bf9a1ac98d'},
#  {'uuid': '2745374eb034ff3b06fdf674d464b51a',
#   'title': 'Acoustic Intelligence Specialist',
#   'normalized_job_title': 'acoustic intelligence specialist',
#   'parent_uuid': 'd84c9cc63f26449f2c83ca44a570e08b'},
#  {'uuid': '4565244fbabcb8f95b61220304354cec',
#   'title': 'Acoustic Sensor Operator',
#   'normalized_job_title': 'acoustic sensor operator',
#   'parent_uuid': 'a0cb417a431b0012234c8ce30d10d3b8'},
#  {'uuid': '5d5ba5b0bc52916e03270223d2774c7a',
#   'title': 'Acoustics Teacher',
#   'normalized_job_title': 'acoustics teacher',
#   'parent_uuid': '048ff2104dda3c986a5500358c86367a'},
#  {'uuid': 'f829e31423a9bfeffafe978b0f6d0884',
#   'title': 'Acquisition Analyst',
#   'normalized_job_title': 'acquisition analyst',
#   'parent_uuid': '5f08fb90f9c24f7151232f10a9a2440c'},
#  {'uuid': '0076a672ec6527d16b1ea080e7227d75',
#   'title': 'Acquisitions Assistant',
#   'normalized_job_title': 'acquisitions assistant',
#   'parent_uuid': 'b30370f068a350a30c1095becb75707a'},
#  {'uuid': 'ac56048ce837154ed19aba41afa3adcd',
#   'title': 'Acquisitions Librarian',
#   'normalized_job_title': 'acquisitions librarian',
#   'parent_uuid': 'dbbb1aac7a8350963ce0295efb70ae81'},
#  {'uuid': 'd6d74b02353e9119402cde773721110a',
#   'title': 'Acquisitions Logistics Analyst',
#   'normalized_job_title': 'acquisitions logistics analyst',
#   'parent_uuid': '5f08fb90f9c24f7151232f10a9a2440c'},
#  {'uuid': 'c68118317fd28e0fa1c9aabc76dcc131',
#   'title': 'Acquisitions Technician',
# ...
#   'parent_uuid': 'e963e743060b8eac35622b5708d08763'},
#  {'uuid': 'c148968d567fbb312abdce98a712568b',
#   'title': 'Admissions Advisor',
#   'normalized_job_title': 'admissions advisor',
#   'parent_uuid': 'a2995c6d482fe453de5f2d7707af44d1'},
#  {'uuid': '3c547af0d73c0af74204845075ce2689',
#   'title': 'Admissions Clerk',
#   'normalized_job_title': 'admissions clerk',
#   'parent_uuid': 'b9395a0c9f252a057e9b153c5c7f4bdd'},
#  {'uuid': '1e7c36c7316ea8de18210ecf22bd104e',
#   'title': 'Admissions Coordinator',
#   'normalized_job_title': 'admissions coordinator',
#   'parent_uuid': '1b98a045acf401bd60c7da36c5d3d117'},
#  {'uuid': '73d0db711fbd9a25d52881343ef14c2c',
#   'title': 'Admissions Counselor',
#   'normalized_job_title': 'admissions counselor',
#   'parent_uuid': 'b9395a0c9f252a057e9b153c5c7f4bdd'},
#  {'uuid': 'c410e2c14c28740aa32ed3049128202c',
#   'title': 'Admissions Dean',
#   'normalized_job_title': 'admissions dean',
#   'parent_uuid': '6f733093f5064e537eff0c4db1288492'},
#  {'uuid': 'd9413ac71071bab7842495ae777a3a73',
#   'title': 'Admissions Director',
#   'normalized_job_title': 'admissions director',
#   'parent_uuid': '6f733093f5064e537eff0c4db1288492'},
#  {'uuid': 'fd9cc8ea7583d263cc87fe7916982a05',
#   'title': 'Admissions Evaluator',
#   'normalized_job_title': 'admissions evaluator',
#   'parent_uuid': '9289770a4f301bb15f6453cca0503de5'},
#  {'uuid': 'b24c5853b5b917d4b09dc660894cc56d',
#   'title': 'Admissions Gate Attendant',
#   'normalized_job_title': 'admissions gate attendant',
#   'parent_uuid': 'a6ee7de3ef174332c2d7302673a602e7'},
#  {'uuid': '6bb58961d52cc13f38ece2383d9bd75a',
#   'title': 'Admissions Officer',
#   'normalized_job_title': 'admissions officer',
#   'parent_uuid': '6f733093f5064e537eff0c4db1288492'},
#  {'uuid': '61640fc96175dfa9e40925f458305173',
#   'title': 'Admissions Representative',
#   'normalized_job_title': 'admissions representative',
#   'parent_uuid': 'b9395a0c9f252a057e9b153c5c7f4bdd'},
#  {'uuid': 'ecda59191e8cfb2c76f4a55a932a0821',
#   'title': 'Admissions Supervisor',
#   'normalized_job_title': 'admissions supervisor',
#   'parent_uuid': '3ffe9bc56a3fd00b02fbdc71c03976f9'},
#  {'uuid': '30e5209389be621cf3a680ddbd39df4e',
#   'title': 'Admittance Attendant',
#   'normalized_job_title': 'admittance attendant',
#   'parent_uuid': '527bf5b48edcac77455daa07a4d63026'},
#  {'uuid': '6562aa67818ee30f0b5bc3fc99cb3505',
#   'title': 'Admitting Clerk',
#   'normalized_job_title': 'admitting clerk',
#   'parent_uuid': 'b9395a0c9f252a057e9b153c5c7f4bdd'},
#  {'uuid': 'a078fdc9d33cce6bc3aa77039cc15632',
#   'title': 'Admitting Counselor',
#   'normalized_job_title': 'admitting counselor',
#   'parent_uuid': 'b9395a0c9f252a057e9b153c5c7f4bdd'},
#  {'uuid': '39f0bb5065228efd45b240383e277c48',
#   'title': 'Admitting Interviewer',
#   'normalized_job_title': 'admitting interviewer',
#   'parent_uuid': 'b9395a0c9f252a057e9b153c5c7f4bdd'},
#  {'uuid': '9a1be4187baeeca3c4034afbd99065f9',
#   'title': 'Admitting Office Escort',
#   'normalized_job_title': 'admitting office escort',
#   'parent_uuid': '4634bbc63c7d257fc47dcf70a02e3021'},
#  {'uuid': 'aea52c3181079aaa04b7720554f8b29d',
#   'title': 'Admitting Officer',
#   'normalized_job_title': 'admitting officer',
#   'parent_uuid': '3ffe9bc56a3fd00b02fbdc71c03976f9'},
#  {'uuid': '9ba57c975c9c30d798a9f7a5d8dfd527',
#   'title': 'Admitting Representative',
#   'normalized_job_title': 'admitting representative',
#   'parent_uuid': 'b9395a0c9f252a057e9b153c5c7f4bdd'},
#  {'uuid': '56ee8051992bd08bc6cb21919d7f0a6e',
#   'title': 'Adobe Block Maker',
#   'normalized_job_title': 'adobe block maker',
#   'parent_uuid': '25bd177078cf3593f9c564249e7c6daa'},
#  {'uuid': '6a131d81772db2cbf6ab607af481dc30',
#   'title': 'Adobe Layer',
#   'normalized_job_title': 'adobe layer',
#   'parent_uuid': 'e361bb1d997e4c215fd15c646be00112'},
#  {'uuid': '5edaddf5f9bf2f4a0c0fd5849c5f8f6f',
#   'title': 'Adobe Layer Helper',
#   'normalized_job_title': 'adobe layer helper',
#   'parent_uuid': '13f8f029b858893c5c6142b2289464e7'},
#  {'uuid': '42b27f7bd39d70a784a7721f20bd1f37',
#   'title': 'Adobe Maker',
#   'normalized_job_title': 'adobe maker',
#   'parent_uuid': '25bd177078cf3593f9c564249e7c6daa'},
#  {'uuid': '76c0ca2219a79852354dbb4acd9c1c2d',
#   'title': 'Adolescent Counselor',
#   'normalized_job_title': 'adolescent counselor',
#   'parent_uuid': 'a76814fe035ad5910922091a663b650f'},
#  {'uuid': '9c10f79d1e598012918c2429b261525c',
#   'title': 'Adolescent Medicine Specialist',
#   'normalized_job_title': 'adolescent medicine specialist',
#   'parent_uuid': '8ca974ae2bf2a135678bc6938c2361c7'},
#  {'uuid': 'f01b195d6ed3daa6b7204fbe6fa4c14d',
#   'title': 'Adoption Agent',
#   'normalized_job_title': 'adoption agent',
#   'parent_uuid': 'a76814fe035ad5910922091a663b650f'},
#  {'uuid': '99dde6bbe30728ca37c2445ef752185b',
#   'title': 'Adoption Coordinator',
#   'normalized_job_title': 'adoption coordinator',
#   'parent_uuid': 'a76814fe035ad5910922091a663b650f'},
#  {'uuid': '02a499ed4800e91a17a819aaa785244a',
#   'title': 'Adoption Counselor',
#   'normalized_job_title': 'adoption counselor',
#   'parent_uuid': 'a76814fe035ad5910922091a663b650f'},
#  {'uuid': 'b2582269b2f05bc9558fad708a8ea690',
#   'title': 'Adoption Services Manager',
#   'normalized_job_title': 'adoption services manager',
#   'parent_uuid': 'd990f3ff4c50f5317407a5ba0f9dcd3b'},
#  {'uuid': '85b2cb36459d0c6c75a7188c832a0671',
#   'title': 'Adoption Social Worker',
#   'normalized_job_title': 'adoption social worker',
#   'parent_uuid': 'a76814fe035ad5910922091a663b650f'},
#  {'uuid': '78bda0fb6e174a8a815063732dc5c19b',
#   'title': 'Adoption Specialist',
#   'normalized_job_title': 'adoption specialist',
#   'parent_uuid': 'a76814fe035ad5910922091a663b650f'},
#  {'uuid': 'd0d7d99f3fde63165d58d9cad189c5bd',
#   'title': 'Adoption Worker',
#   'normalized_job_title': 'adoption worker',
#   'parent_uuid': 'a76814fe035ad5910922091a663b650f'},
#  {'uuid': '4bd94c0283314d53c9d4d86e65b37be8',
#   'title': 'Ad Setter',
#   'normalized_job_title': 'ad setter',
#   'parent_uuid': 'fea86e75b6ff86f198928a9a7697972b'},
#  {'uuid': '7b695d184872c4b69229996bc7b2d087',
#   'title': 'Ad Taker',
#   'normalized_job_title': 'ad taker',
#   'parent_uuid': 'c87104a767ffe5f817fb497d8794802e'},
#  {'uuid': '5ea65a1af9341e373716ddee3ba25e2b',
#   'title': 'Adult and Pediatric Neurologist',
#   'normalized_job_title': 'adult and pediatric neurologist',
#   'parent_uuid': 'e3d7af48ea17637c2f2385c18db79724'},
#  {'uuid': 'fe4e58da476229b131f2a662dacadd4d',
#   'title': 'Adult Basic Education Instructor',
#   'normalized_job_title': 'adult basic education instructor',
#   'parent_uuid': '620195c432b4b7f5c99d8eb8c1c8d3a6'},
#  {'uuid': '927a743e8af1adef4e16cd6f87edd4c3',
#   'title': 'Adult Basic Education Instructor (ABE Instructor)',
#   'normalized_job_title': 'adult basic education instructor abe instructor',
#   'parent_uuid': '5c6c8a449073aa00fe602b7fe37ff96e'},
#  {'uuid': '30ca021aa0e5676a75cb019ac8605343',
#   'title': 'Adult Basic Education Manager',
#   'normalized_job_title': 'adult basic education manager',
#   'parent_uuid': '6f733093f5064e537eff0c4db1288492'},
#  {'uuid': '64dd80102ff0ee70050fe695a44f40f9',
#   'title': 'Adult Basic Education Teacher (ABE Teacher)',
#   'normalized_job_title': 'adult basic education teacher abe teacher',
#   'parent_uuid': '5c6c8a449073aa00fe602b7fe37ff96e'},
#  {'uuid': '3944d6fff8e46ab141f6325d8910becf',
#   'title': 'Adult Basic Studies Teacher',
#   'normalized_job_title': 'adult basic studies teacher',
#   'parent_uuid': '5c6c8a449073aa00fe602b7fe37ff96e'},
#  {'uuid': '2a32cc3f031841d711a2e1eaf8b101bd',
#   'title': 'Adult Crossing Guard',
#   'normalized_job_title': 'adult crossing guard',
#   'parent_uuid': 'be14c7935b47e280e934d8908fa8f00c'},
#  {'uuid': '72238d914590c76daef68ab017ec1e42',
#   'title': 'Adult Daycare Coordinator',
#   'normalized_job_title': 'adult daycare coordinator',
#   'parent_uuid': 'd990f3ff4c50f5317407a5ba0f9dcd3b'},
#  {'uuid': '22ed23c3dfe30d0ae0c7599941708269',
#   'title': 'Adult Education Instructor',
#   'normalized_job_title': 'adult education instructor',
#   'parent_uuid': '5c6c8a449073aa00fe602b7fe37ff96e'},
#  {'uuid': '8aec4e3d8578ff4fccb4a60d914aea07',
#   'title': 'Adult Education Teacher',
#   'normalized_job_title': 'adult education teacher',
#   'parent_uuid': '5c6c8a449073aa00fe602b7fe37ff96e'},
#  {'uuid': '6dea9c33446a289cba62cd1d2f7afd22',
#   'title': 'Adult Educator',
#   'normalized_job_title': 'adult educator',
#   'parent_uuid': 'f4bb6561784afc33704b64005d89cfce'},
#  {'uuid': 'd47b74e1eccb243b69b88c234b45b25f',
#   'title': 'Adult Family Home Program Manager',
#   'normalized_job_title': 'adult family home program manager',
#   'parent_uuid': 'e41414f8f819f602059013609ac73ddb'},
#  {'uuid': 'ddb9585652d09e5086f1e71d541dbc14',
#   'title': 'Adult Health Clinical Nurse Specialist',
#   'normalized_job_title': 'adult health clinical nurse specialist',
#   'parent_uuid': 'ceebffa1a369da0c4ebacf2722f95768'},
#  {'uuid': '4010f60ab9c153ceabac77cb762d9b2d',
#   'title': 'Adult High School Instructor',
#   'normalized_job_title': 'adult high school instructor',
#   'parent_uuid': '5c6c8a449073aa00fe602b7fe37ff96e'},
#  {'uuid': 'ec705e17dd29bd4dc256737b5ae123cc',
#   'title': 'Adult Literacy Instructor',
#   'normalized_job_title': 'adult literacy instructor',
#   'parent_uuid': '5c6c8a449073aa00fe602b7fe37ff96e'},
#  {'uuid': '90243b1216df74bcbde61ee695b05178',
#   'title': 'Adult Literacy Teacher',
#   'normalized_job_title': 'adult literacy teacher',
#   'parent_uuid': '5c6c8a449073aa00fe602b7fe37ff96e'},
#  {'uuid': '8fe79258248020956e01f21ef9c65ad4',
#   'title': 'Adult Ministries Director',
#   'normalized_job_title': 'adult ministries director',
#   'parent_uuid': '2e901f99e57840876385aa4f7d2b8f8e'},
#  {'uuid': '5bf24fa30eabf8cbeb99601ee121999b',
#   'title': 'Adult Neurologist',
#   'normalized_job_title': 'adult neurologist',
#   'parent_uuid': 'e3d7af48ea17637c2f2385c18db79724'},
#  {'uuid': '0dbf60bc8bc254d8c8867e13add61d87',
#   'title': 'Adult Neuropsychologist',
#   'normalized_job_title': 'adult neuropsychologist',
#   'parent_uuid': '7172162b3576ec5839dd18d7d5c75dc7'},
#  {'uuid': '44a4fbd9dd5b82d7b58eed72c7ed3374',
#   'title': 'Adult Nurse Practitioner',
#   'normalized_job_title': 'adult nurse practitioner',
#   'parent_uuid': 'ebf66ea29e40fe94d8f0ff7a452c8558'},
#  {'uuid': 'fcd1bcf832abfef69627243a150767fb',
#   'title': 'Adult Parole Officer',
#   'normalized_job_title': 'adult parole officer',
#   'parent_uuid': '64848aac754111a0b7e250e80de47233'},
#  {'uuid': '15c7e5c0f8985b3f26bb0ab5fc43b009',
#   'title': 'Adult Probation Officer',
#   'normalized_job_title': 'adult probation officer',
#   'parent_uuid': '64848aac754111a0b7e250e80de47233'},
#  {'uuid': 'e37989cf6380f5872cbd13aeda021da1',
#   'title': 'Adult Protective Caseworker',
#   'normalized_job_title': 'adult protective caseworker',
#   'parent_uuid': 'a76814fe035ad5910922091a663b650f'},
#  {'uuid': '7142fe7e0e84ccbcf21b397037ed7477',
#   'title': 'Adult Psychiatric Mental Health Nurse Practitioner',
#   'normalized_job_title': 'adult psychiatric mental health nurse practitioner',
#   'parent_uuid': 'ca7aec7f560fd1528f46d48ca3b51721'},
#  {'uuid': '36e18487f710cb04b7b9539cef428b2d',
#   'title': 'Adult Psychiatric-Mental Health Nurse Practitioner',
#   'normalized_job_title': 'adult psychiatricmental health nurse practitioner',
#   'parent_uuid': 'ca7aec7f560fd1528f46d48ca3b51721'},
#  {'uuid': '5aebc1f063959897ec96c960f243420d',
#   'title': 'Adult Psychiatrist',
#   'normalized_job_title': 'adult psychiatrist',
#   'parent_uuid': 'aad2d7bd12f02b0eae6f087c0c4ff799'},
#  {'uuid': '8588a80b5f0101299a676a88f3ab20ec',
#   'title': 'Adult Reference Librarian',
#   'normalized_job_title': 'adult reference librarian',
#   'parent_uuid': 'dbbb1aac7a8350963ce0295efb70ae81'},
#  {'uuid': 'f2e1ca45c298322fa9b900fa9907f1b2',
#   'title': 'Adult Remedial Education Instructor',
#   'normalized_job_title': 'adult remedial education instructor',
#   'parent_uuid': '5c6c8a449073aa00fe602b7fe37ff96e'},
#  {'uuid': 'af852a7cf494a3812b610f8105902ad3',
#   'title': 'Adult School Counselor',
#   'normalized_job_title': 'adult school counselor',
#   'parent_uuid': 'a2995c6d482fe453de5f2d7707af44d1'},
#  {'uuid': 'f8fef20cfd69fcbf1e3d401b720da063',
#   'title': 'Adult School Teacher',
#   'normalized_job_title': 'adult school teacher',
#   'parent_uuid': '5c6c8a449073aa00fe602b7fe37ff96e'},
#  {'uuid': 'd97a3c0d7b797790625e9b764c6dc28c',
#   'title': 'Adult Secondary Education Instructor',
#   'normalized_job_title': 'adult secondary education instructor',
#   'parent_uuid': '5c6c8a449073aa00fe602b7fe37ff96e'},
#  {'uuid': '38c5b26d238e01f974a0d77e783a34cf',
#   'title': 'Adult Services Librarian',
#   'normalized_job_title': 'adult services librarian',
#   'parent_uuid': 'dbbb1aac7a8350963ce0295efb70ae81'},
#  {'uuid': '02302946af215586b1a94684ab80fd89',
#   'title': 'Advance Agent',
#   'normalized_job_title': 'advance agent',
#   'parent_uuid': '5dc51759bcb608b7f4d990e36a89d42e'},
#  {'uuid': 'e1abe2a1f1a92a2644349346d0b85748',
#   'title': 'Advanced Clinical Specialist',
#   'normalized_job_title': 'advanced clinical specialist',
#   'parent_uuid': '7bbe67cb54b2e639a6a6e3fe505e54bb'},
#  {'uuid': '03eb70e0bf2c41f597c692dd9c3e54ba',
#   'title': 'Advanced Computer Aided Design Specialist (Advanced CAD Specialist)',
#   'normalized_job_title': 'advanced computer aided design specialist advanced cad specialist',
#   'parent_uuid': '4751f975c16158b9566dd65e088001e1'},
#  {'uuid': 'c917d3c47f803c030e8b0aad7c096c5c',
#   'title': 'Advanced Diagnostics Engineering Specialist',
#   'normalized_job_title': 'advanced diagnostics engineering specialist',
#   'parent_uuid': '4751f975c16158b9566dd65e088001e1'},
#  {'uuid': 'e889689ae03704b0b6f605130767edbb',
#   'title': 'Advanced Electronic Field Production Specialist (Advanced EFP Specialist)',
#   'normalized_job_title': 'advanced electronic field production specialist advanced efp specialist',
#   'parent_uuid': 'd7f09579cb56c6aa9beace7d9aac658a'},
#  {'uuid': '884e63b612a61b5b076187b82d76b5c6',
#   'title': 'Advanced Foreign Counterintelligence Officer (Afco)',
#   'normalized_job_title': 'advanced foreign counterintelligence officer afco',
#   'parent_uuid': '06dd2fcfd18994fa1bbb4d0b130983c9'},
#  {'uuid': '852443025c31f7e8846b763300dd4184',
#   'title': 'Advanced Foreign Counterintelligence Specialist (AFCS)',
#   'normalized_job_title': 'advanced foreign counterintelligence specialist afcs',
#   'parent_uuid': '38fa0f1e4f3af4981a3bce137272c212'},
#  {'uuid': 'fb8da1c4b010b32f151c5a4e7d98ad89',
#   'title': 'Advanced Manufacturing Associate',
#   'normalized_job_title': 'advanced manufacturing associate',
#   'parent_uuid': 'e111872533184d3a0a0dbbb5739f50c8'},
#  {'uuid': 'a3e089b07ac8660b5d3d46abe8627cbc',
#   'title': 'Advanced Manufacturing Consultant',
#   'normalized_job_title': 'advanced manufacturing consultant',
#   'parent_uuid': '4751f975c16158b9566dd65e088001e1'},
#  {'uuid': 'd4195c4a24dd9a957d72e04904fdfa66',
#   'title': 'Advanced Manufacturing Technician',
#   'normalized_job_title': 'advanced manufacturing technician',
#   'parent_uuid': '98de71a2b00a1c9d904ea3465884889f'},
#  {'uuid': 'd33e11c696ad4879ade1dfdb1825f1a2',
#   'title': 'Advanced Military Source Operations Officer (Amsoo)',
#   'normalized_job_title': 'advanced military source operations officer amsoo',
#   'parent_uuid': '06dd2fcfd18994fa1bbb4d0b130983c9'},
#  {'uuid': 'b336cb9e4c4371116af7a810c386cd5b',
#   'title': 'Advanced Military Source Operations Specialist (AMOS)',
#   'normalized_job_title': 'advanced military source operations specialist amos',
#   'parent_uuid': '38fa0f1e4f3af4981a3bce137272c212'},
#  {'uuid': 'e2de516c216cb38540cc55ce01391e4f',
#   'title': 'Advanced Nursing Professor',
#   'normalized_job_title': 'advanced nursing professor',
#   'parent_uuid': 'f11ff6b88b2dfb6a10020ee596cf8844'},
#  {'uuid': 'e28657025fb7b66ff64c951d03702559',
#   'title': 'Advanced Practice Nurse, Cardiothoracic Surgery',
#   'normalized_job_title': 'advanced practice nurse cardiothoracic surgery',
#   'parent_uuid': 'ceebffa1a369da0c4ebacf2722f95768'},
#  {'links': [{'rel': 'self', 'href': '/jobs?offset=0&limit=500'},
#    {'rel': 'first', 'href': '/jobs?offset=0&limit=500'},
#    {'rel': 'next', 'href': '/jobs?offset=500&limit=500'},
#    {'rel': 'last', 'href': '/jobs?offset=45500&limit=500'}]}]
